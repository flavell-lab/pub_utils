# %%
import pandas as pd
import pub_utils as pu

# %% [markdown]
# ## Monoamine Connectome

# %%
path_csv = '../data/RipollSanchez2023/monoamine_connectome_08062023.csv'
title = 'Monoamine Connectome - RipollSanchez2023'
colorbar_label = '# Unique Ligand Projections\n(different receptors for same ligand is counted once)'
path_df = '../connectomes/preassembled/monoamine_RipollSanchez2023.csv'
path_fig = '../plots/monoamine_RipollSanchez2023.png'

# Read from csv
df = pd.read_csv(path_csv)

# Standardize and save
std_df = pu.standardize_dataframe(df, pu.AllHermNeurons)
std_df.to_csv(path_df)

# Plot and save
std_fig = pu.plot_connectome_matrix(std_df, title=title, colorbar_label=colorbar_label)
std_fig.savefig(path_fig, dpi=600, bbox_inches='tight')

# %% [markdown]
# ## Neuropeptide Connectome

# %%
path_csv = '../data/RipollSanchez2023/NPP_connectome_short_range_01022024.csv'
title = 'Neuropeptide Connectome - RipollSanchez2023 (Short Range)'
path_df = '../connectomes/preassembled/NPP_RipollSanchez2023_shortRange.csv'
path_fig = '../plots/NPP_RipollSanchez2023_shortRange.png'

# Read from csv
df = pd.read_csv(path_csv)

# Standardize and save
std_df = pu.standardize_dataframe(df, pu.AllHermNeurons)
std_df.to_csv(path_df)

# Plot and save
std_fig = pu.plot_connectome_matrix(std_df, title=title)
std_fig.savefig(path_fig, dpi=600, bbox_inches='tight')

# %%
path_csv = '../data/RipollSanchez2023/NPP_connectome_mid_range_01022024.csv'
title = 'Neuropeptide Connectome - RipollSanchez2023 (Mid Range)'
path_df = '../connectomes/preassembled/NPP_RipollSanchez2023_midRange.csv'
path_fig = '../plots/NPP_RipollSanchez2023_midRange.png'

# Read from csv
df = pd.read_csv(path_csv)

# Standardize and save
std_df = pu.standardize_dataframe(df, pu.AllHermNeurons)
std_df.to_csv(path_df)

# Plot and save
std_fig = pu.plot_connectome_matrix(std_df, title=title)
std_fig.savefig(path_fig, dpi=600, bbox_inches='tight')

# %%
path_csv = '../data/RipollSanchez2023/NPP_connectome_long_range_01022024.csv'
title = 'Neuropeptide Connectome - RipollSanchez2023 (Long Range)'
path_df = '../connectomes/preassembled/NPP_RipollSanchez2023_longRange.csv'
path_fig = '../plots/NPP_RipollSanchez2023_longRange.png'

# Read from csv
df = pd.read_csv(path_csv)

# Standardize and save
std_df = pu.standardize_dataframe(df, pu.AllHermNeurons)
std_df.to_csv(path_df)

# Plot and save
std_fig = pu.plot_connectome_matrix(std_df, title=title)
std_fig.savefig(path_fig, dpi=600, bbox_inches='tight')

# %% [markdown]
# ## Individual NPP-GPCR pairs

# %%
# Define
npp = 'FLP-10'
gpcr = 'DMSR-1'
file_idx = pu.get_file_for_pair(npp, gpcr)

path_csv = f'../data/RipollSanchez2023/individual/individual_mid_range/{file_idx}.csv'
title = f'{npp} -> {gpcr} Connectome - RipollSanchez2023 (Mid Range)'
path_df = f'../connectomes/preassembled/{npp}_{gpcr}_RipollSanchez2023_midRange.csv'
path_fig = f'../plots/{npp}_{gpcr}_RipollSanchez2023_midRange.png'

# Read from csv
df = pd.read_csv(path_csv)

# Standardize and save
std_df = pu.standardize_dataframe(df, pu.AllHermNeurons)
std_df.to_csv(path_df)

# Plot and save
std_fig = pu.plot_connectome_matrix(std_df, title=title)
std_fig.savefig(path_fig, dpi=600, bbox_inches='tight')
