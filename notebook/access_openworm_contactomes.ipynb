# %% [markdown]
# ## Brittin2021 - L4 (neuropil) x1, adult hermaphrodite (neuropil) x1
# Instead of synapses, membrane contact was quantified

# %%
from cect.BrittinDataReader import get_instance

dataset = get_instance()
print(dataset.summary())
nodes = dataset.nodes
contact = dataset.connections['Contact']
# Out:
# cect      >>>  Opened sheet <Worksheet "M"> in Excel file: /store1/shared/pub_utils/.venv/lib/python3.10/site-packages/cect/data/41586_2021_3284_MOESM5_ESM.xlsx
# cect      >>>  Finished processing 173 cells, 160 bilateral and 13 single cells: ['ALA', 'AQR', 'AVL', 'AVM', 'DVA', 'DVC', 'PVT', 'RID', 'RIH', 'RIR', 'RIS', 'RMED', 'RMEV']
# cect      >>>  Preexisting connection (223 conns already) w: 77296.000000 at (78,77) - new one: Connection from AVKL to AVKR (77296 times, type: Contact, neurotransmitter: Contact)...
# cect      >>>  Same weight...
# cect      >>>  Preexisting connection (224 conns already) w: 77296.000000 at (77,78) - new one: Connection from AVKR to AVKL (77296 times, type: Contact, neurotransmitter: Contact)...
# cect      >>>  Same weight...
# cect      >>>  Preexisting connection (279 conns already) w: 1302.500000 at (94,93) - new one: Connection from AIMR to AIML (1302.5 times, type: Contact, neurotransmitter: Contact)...
# cect      >>>  Same weight...
# ...

# %%
plt.imshow(contact)
plt.colorbar()

# %% [markdown]
# ## Yim2024 - Dauer
#
# Volumetric reconstruction and synaptic annotation was automated

# %%
from cect.Yim2024NonNormDataReader import get_instance

dataset = get_instance()
print(dataset.summary())

nodes = dataset.nodes
contact = dataset.connections['Contact']
# Out:
# /store1/shared/pub_utils/.venv/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# cect      >>>  Opened the Excel file: /store1/shared/pub_utils/.venv/lib/python3.10/site-packages/cect/data/elife-95402-supp2-v1.xlsx
# Reading row 5
# cect      >>>  Reading row 5: ADAL, NTs: Glutamate, None, None; cat_1_present: False, snf_3_present: False
# cect      >>>    - Cell: ADAL, nts: ['Glutamate']
# Reading row 6
# cect      >>>  Reading row 6: ADAR, NTs: Glutamate, None, None; cat_1_present: False, snf_3_present: False
# cect      >>>    - Cell: ADAR, nts: ['Glutamate']
# Reading row 7
# cect      >>>  Reading row 7: ADEL, NTs: Dopamine, None, None; cat_1_present: True, snf_3_present: False
# cect      >>>    - Cell: ADEL, nts: ['Dopamine']
# Reading row 8
# cect      >>>  Reading row 8: ADER, NTs: Dopamine, None, None; cat_1_present: True, snf_3_present: False
# ...

# %%
plt.imshow(contact)
plt.colorbar()
