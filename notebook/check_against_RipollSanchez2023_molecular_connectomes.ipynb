# %% [markdown]
# ## This notebook is generated entirely by Claude Code (Opus)

# %%
import sys
sys.path.insert(0, '/storage/fs/store1/shared/pub_utils/src')

from pub_utils.assemble import assemble_npp_connectome, get_npp_release_vector, get_npp_receptor_matrix

# Test with FLP-1 and RipollSanchez2023 assets
neuropeptide = 'flp-1'
release_sources = ['sequencing:RipollSanchez2023']
receptor_sources = ['sequencing:RipollSanchez2023']
pairing_source = 'RipollSanchez2023'

# First, check the release vector for FLP-1
release = get_npp_release_vector(neuropeptide, release_sources)
print("FLP-1 Release Vector (neurons expressing FLP-1):")
print(f"  Shape: {release.shape}")
print(f"  Sum (releasing neurons): {release.sum()}")
print(f"  Non-NaN count: {release.notna().sum()}")
releasing_neurons = release[release == 1].index.tolist()
print(f"  Neurons releasing FLP-1: {releasing_neurons}")
# Check the receptor matrix for FLP-1 (which includes DMSR-7 based on pairing info)
receptor = get_npp_receptor_matrix(neuropeptide, receptor_sources, pairing_source)
print("FLP-1 Receptor Matrix (receptors responding to FLP-1):")
print(f"  Shape: {receptor.shape}")
print(f"  Receptors found: {receptor.columns.tolist()}")

# Check DMSR-7 specifically
if 'dmsr-7' in receptor.columns:
    dmsr7_col = receptor['dmsr-7']
    print(f"\nDMSR-7 expression:")
    print(f"  Sum (expressing neurons): {dmsr7_col.sum()}")
    expressing = dmsr7_col[dmsr7_col == 1].index.tolist()
    print(f"  Neurons expressing DMSR-7: {expressing}")
else:
    print("\nDMSR-7 not found in receptor matrix columns")
    
# Assemble the full NPP connectome for FLP-1
connectome = assemble_npp_connectome(
    neuropeptide='flp-1',
    release_sources=['sequencing:RipollSanchez2023'],
    receptor_sources=['sequencing:RipollSanchez2023'],
    pairing_source='RipollSanchez2023',
    receptor_gate='or',
    output_format='binary'
)

print("FLP-1 Connectome (binary, all receptors):")
print(f"  Shape: {connectome.shape}")
print(f"  Total connections: {int(connectome.sum().sum())}")
print(f"  Source neurons: {(connectome.sum(axis=1) > 0).sum()}")
print(f"  Target neurons: {(connectome.sum(axis=0) > 0).sum()}")

# Show the actual connections (source -> target)
connections = []
for src in connectome.index:
    for tgt in connectome.columns:
        if connectome.loc[src, tgt] == 1:
            connections.append((src, tgt))
            
print(f"\nConnections (source -> target) [{len(connections)} total]:")
for src, tgt in sorted(connections):
    print(f"  {src} -> {tgt}")
# Now test specifically the FLP-1 + DMSR-7 pair using per_pair output
per_pair = assemble_npp_connectome(
    neuropeptide='flp-1',
    release_sources=['sequencing:RipollSanchez2023'],
    receptor_sources=['sequencing:RipollSanchez2023'],
    pairing_source='RipollSanchez2023',
    receptor_gate='or',
    output_format='per_pair'
)

print("Per-receptor connectomes available:")
for receptor, matrix in per_pair.items():
    total_conn = int(matrix.sum().sum())
    print(f"  {receptor}: {total_conn} connections")

# Show FLP-1 -> DMSR-7 specific connections
print("\n" + "="*60)
print("FLP-1 -> DMSR-7 Connectome:")
print("="*60)
dmsr7_matrix = per_pair['dmsr-7']
print(f"Shape: {dmsr7_matrix.shape}")
print(f"Total connections: {int(dmsr7_matrix.sum().sum())}")

# Show connections
dmsr7_connections = []
for src in dmsr7_matrix.index:
    for tgt in dmsr7_matrix.columns:
        if dmsr7_matrix.loc[src, tgt] == 1:
            dmsr7_connections.append((src, tgt))
            
print(f"\nFLP-1/DMSR-7 connections ({len(dmsr7_connections)} total):")
for src, tgt in sorted(dmsr7_connections):
    print(f"  {src} -> {tgt}")
import pandas as pd
import numpy as np

# Load the preassembled connectome
preassembled_path = '/storage/fs/store1/shared/pub_utils/connectomes/preassembled/molecular/FLP-1_DMSR-7_RipollSanchez2023_longRange.csv'
preassembled = pd.read_csv(preassembled_path, index_col=0)

print("Preassembled FLP-1/DMSR-7 connectome:")
print(f"  Shape: {preassembled.shape}")
print(f"  Total connections: {int(preassembled.sum().sum())}")
print(f"  Source neurons with outgoing: {(preassembled.sum(axis=1) > 0).sum()}")
print(f"  Target neurons with incoming: {(preassembled.sum(axis=0) > 0).sum()}")

# Get our assembled connectome (dmsr-7 specific)
assembled = per_pair['dmsr-7']

print("\nAssembled FLP-1/DMSR-7 connectome:")
print(f"  Shape: {assembled.shape}")
print(f"  Total connections: {int(assembled.sum().sum())}")
print(f"  Source neurons with outgoing: {(assembled.sum(axis=1) > 0).sum()}")
print(f"  Target neurons with incoming: {(assembled.sum(axis=0) > 0).sum()}")
# Detailed comparison
# Align indices for comparison
common_idx = preassembled.index.intersection(assembled.index)
common_col = preassembled.columns.intersection(assembled.columns)

print(f"Common neurons in index: {len(common_idx)}")
print(f"Common neurons in columns: {len(common_col)}")

# Compare on common neurons
pre_aligned = preassembled.loc[common_idx, common_col]
asm_aligned = assembled.loc[common_idx, common_col]

# Check for exact match
exact_match = (pre_aligned == asm_aligned).all().all()
print(f"\nExact match: {exact_match}")

if not exact_match:
    # Find differences
    diff = pre_aligned != asm_aligned
    diff_count = diff.sum().sum()
    print(f"Number of differences: {diff_count}")
    
    # Show specific differences
    for src in common_idx:
        for tgt in common_col:
            if pre_aligned.loc[src, tgt] != asm_aligned.loc[src, tgt]:
                print(f"  {src} -> {tgt}: preassembled={pre_aligned.loc[src, tgt]}, assembled={asm_aligned.loc[src, tgt]}")
else:
    print("All 302x302 = 91,204 entries match exactly!")
    
# Additional validation: check source neurons
pre_sources = preassembled.index[(preassembled.sum(axis=1) > 0)].tolist()
asm_sources = assembled.index[(assembled.sum(axis=1) > 0)].tolist()
print(f"\nSource neurons (preassembled): {pre_sources}")
print(f"Source neurons (assembled): {asm_sources}")
print(f"Sources match: {pre_sources == asm_sources}")

# Check target neurons
pre_targets = preassembled.columns[(preassembled.sum(axis=0) > 0)].tolist()
asm_targets = assembled.columns[(assembled.sum(axis=0) > 0)].tolist()
print(f"\nTarget neurons match: {set(pre_targets) == set(asm_targets)}")
print(f"Number of targets: {len(pre_targets)}")
# Additional validation: verify intermediate data
print("="*60)
print("Intermediate Data Validation")
print("="*60)

# 1. Pairing info validation
from pub_utils.assemble import _load_npp_pairing_info
pairing = _load_npp_pairing_info('RipollSanchez2023')
flp1_dmsr7_pair = pairing[(pairing['ligand'] == 'flp-1') & (pairing['receptor'] == 'dmsr-7')]
print("\n1. Pairing Info (RipollSanchez2023):")
print(f"   FLP-1 / DMSR-7 pair found: {len(flp1_dmsr7_pair) > 0}")
if len(flp1_dmsr7_pair) > 0:
    print(f"   EC50: {flp1_dmsr7_pair['EC50'].values[0]}")

# 2. Release data validation
from pub_utils.assemble import _load_npp_release_data
release_data = _load_npp_release_data('sequencing', 'RipollSanchez2023')
release_data.columns = release_data.columns.str.lower()
flp1_release = release_data['flp-1']
releasing_neurons = flp1_release[flp1_release == 1].index.tolist()
print("\n2. Release Data (sequencing:RipollSanchez2023):")
print(f"   FLP-1 column exists: {'flp-1' in release_data.columns}")
print(f"   Neurons releasing FLP-1: {releasing_neurons}")

# 3. Receptor data validation
from pub_utils.assemble import _load_npp_receptor_data
receptor_data = _load_npp_receptor_data('sequencing', 'RipollSanchez2023')
dmsr7_expr = receptor_data['dmsr-7']
expressing_neurons = dmsr7_expr[dmsr7_expr == 1].index.tolist()
print("\n3. Receptor Data (sequencing:RipollSanchez2023):")
print(f"   DMSR-7 column exists: {'dmsr-7' in receptor_data.columns}")
print(f"   Neurons expressing DMSR-7: {len(expressing_neurons)}")

# 4. Verify connection count = sources × targets
expected_connections = len(releasing_neurons) * len(expressing_neurons)
print(f"\n4. Connection Count Validation:")
print(f"   Expected: {len(releasing_neurons)} sources × {len(expressing_neurons)} targets = {expected_connections}")
print(f"   Actual: {int(assembled.sum().sum())}")
print(f"   Match: {expected_connections == int(assembled.sum().sum())}")
# Out:
# FLP-1 Release Vector (neurons expressing FLP-1):
#   Shape: (302,)
#   Sum (releasing neurons): 2
#   Non-NaN count: 302
#   Neurons releasing FLP-1: ['AVKL', 'AVKR']
# FLP-1 Receptor Matrix (receptors responding to FLP-1):
#   Shape: (302, 4)
#   Receptors found: ['dmsr-5', 'dmsr-6', 'dmsr-7', 'frpr-7']
#
# DMSR-7 expression:
#   Sum (expressing neurons): 102
#   Neurons expressing DMSR-7: ['ALML', 'ALMR', 'AVM', 'SDQL', 'SDQR', 'URBL', 'URBR', 'DVA', 'ALA', 'RIAL', 'RIAR', 'RIBL', 'RIBR', 'RICL', 'RICR', 'RIH', 'AVFL', 'AVFR', 'AVKL', 'AVKR', 'PVPL', 'PVPR', 'PVR', 'PVT', 'RID', 'PVCL', 'PVCR', 'AVAL', 'AVAR', 'AVBL', 'AVBR', 'AVDL', 'AVDR', 'SABD', 'SABVL', 'SABVR', 'RIML', 'RIMR', 'RMDDL', 'RMDDR', 'RMDVL', 'RMDVR', 'RMED', 'RMEV', 'RMHL', 'RMHR', 'SMDDL', 'SMDDR', 'SMDVL', 'SMDVR', 'DA01', 'DA02', 'DA03', 'DA04', 'DA05', 'DA06', 'DA07', 'DA08', 'DA09', 'DB01', 'DB02', 'DB03', 'DB04', 'DB05', 'DB06', 'DB07', 'AS01', 'AS02', 'AS03', 'AS04', 'AS05', 'AS06', 'AS07', 'AS08', 'AS09', 'AS10', 'AS11', 'PDB', 'VA01', 'VA02', 'VA03', 'VA04', 'VA05', 'VA06', 'VA07', 'VA08', 'VA09', 'VA10', 'VA11', 'VB01', 'VB02', 'VB03', 'VB04', 'VB05', 'VB06', 'VB07', 'VB08', 'VB09', 'VB10', 'VB11', 'HSNL', 'HSNR']
# FLP-1 Connectome (binary, all receptors):
#   Shape: (302, 302)
#   Total connections: 384
#   Source neurons: 2
#   Target neurons: 192
#
# Connections (source -> target) [384 total]:
#   AVKL -> ADAL
#   AVKL -> ADAR
#   AVKL -> ADEL
#   AVKL -> ADER
#   AVKL -> ADFL
#   AVKL -> ADFR
#   AVKL -> AIAL
#   AVKL -> AIAR
#   AVKL -> ALA
#   AVKL -> ALML
#   AVKL -> ALMR
#   AVKL -> AS01
#   AVKL -> AS02
#   AVKL -> AS03
#   AVKL -> AS04
#   AVKL -> AS05
#   AVKL -> AS06
#   AVKL -> AS07
#   AVKL -> AS08
#   AVKL -> AS09
#   AVKL -> AS10
#   AVKL -> AS11
#   AVKL -> ASJL
#   AVKL -> ASJR
#   AVKL -> AVAL
#   AVKL -> AVAR
#   AVKL -> AVBL
#   AVKL -> AVBR
#   AVKL -> AVDL
#   AVKL -> AVDR
#   AVKL -> AVEL
#   AVKL -> AVER
#   AVKL -> AVFL
#   AVKL -> AVFR
#   AVKL -> AVG
#   AVKL -> AVKL
#   AVKL -> AVKR
#   AVKL -> AVM
#   AVKL -> DA01
#   AVKL -> DA02
#   AVKL -> DA03
#   AVKL -> DA04
#   AVKL -> DA05
#   AVKL -> DA06
#   AVKL -> DA07
#   AVKL -> DA08
#   AVKL -> DA09
#   AVKL -> DB01
#   AVKL -> DB02
#   AVKL -> DB03
#   AVKL -> DB04
#   AVKL -> DB05
#   AVKL -> DB06
#   AVKL -> DB07
#   AVKL -> DD01
#   AVKL -> DD02
#   AVKL -> DD03
#   AVKL -> DD04
#   AVKL -> DD05
#   AVKL -> DD06
#   AVKL -> DVA
#   AVKL -> FLPL
#   AVKL -> FLPR
#   AVKL -> HSNL
#   AVKL -> HSNR
#   AVKL -> I1L
#   AVKL -> I1R
#   AVKL -> I3
#   AVKL -> I4
#   AVKL -> IL2DL
#   AVKL -> IL2DR
#   AVKL -> IL2L
#   AVKL -> IL2R
#   AVKL -> IL2VL
#   AVKL -> IL2VR
#   AVKL -> LUAL
#   AVKL -> LUAR
#   AVKL -> M1
#   AVKL -> M3L
#   AVKL -> M3R
#   AVKL -> M4
#   AVKL -> M5
#   AVKL -> MCL
#   AVKL -> MCR
#   AVKL -> MI
#   AVKL -> NSML
#   AVKL -> NSMR
#   AVKL -> PDA
#   AVKL -> PDB
#   AVKL -> PDEL
#   AVKL -> PDER
#   AVKL -> PHCL
#   AVKL -> PHCR
#   AVKL -> PLML
#   AVKL -> PLMR
#   AVKL -> PQR
#   AVKL -> PVCL
#   AVKL -> PVCR
#   AVKL -> PVDL
#   AVKL -> PVDR
#   AVKL -> PVNL
#   AVKL -> PVNR
#   AVKL -> PVPL
#   AVKL -> PVPR
#   AVKL -> PVQL
#   AVKL -> PVQR
#   AVKL -> PVR
#   AVKL -> PVT
#   AVKL -> PVWL
#   AVKL -> PVWR
#   AVKL -> RIAL
#   AVKL -> RIAR
#   AVKL -> RIBL
#   AVKL -> RIBR
#   AVKL -> RICL
#   AVKL -> RICR
#   AVKL -> RID
#   AVKL -> RIGL
#   AVKL -> RIGR
#   AVKL -> RIH
#   AVKL -> RIML
#   AVKL -> RIMR
#   AVKL -> RIS
#   AVKL -> RMDDL
#   AVKL -> RMDDR
#   AVKL -> RMDL
#   AVKL -> RMDR
#   AVKL -> RMDVL
#   AVKL -> RMDVR
#   AVKL -> RMED
#   AVKL -> RMEV
#   AVKL -> RMGL
#   AVKL -> RMGR
#   AVKL -> RMHL
#   AVKL -> RMHR
#   AVKL -> SABD
#   AVKL -> SABVL
#   AVKL -> SABVR
#   AVKL -> SDQL
#   AVKL -> SDQR
#   AVKL -> SMDDL
#   AVKL -> SMDDR
#   AVKL -> SMDVL
#   AVKL -> SMDVR
#   AVKL -> URADL
#   AVKL -> URADR
#   AVKL -> URAVL
#   AVKL -> URAVR
#   AVKL -> URBL
#   AVKL -> URBR
#   AVKL -> URXL
#   AVKL -> URXR
#   AVKL -> URYDL
#   AVKL -> URYDR
#   AVKL -> URYVL
#   AVKL -> URYVR
#   AVKL -> VA01
#   AVKL -> VA02
#   AVKL -> VA03
#   AVKL -> VA04
#   AVKL -> VA05
#   AVKL -> VA06
#   AVKL -> VA07
#   AVKL -> VA08
#   AVKL -> VA09
#   AVKL -> VA10
#   AVKL -> VA11
#   AVKL -> VA12
#   AVKL -> VB01
#   AVKL -> VB02
#   AVKL -> VB03
#   AVKL -> VB04
#   AVKL -> VB05
#   AVKL -> VB06
#   AVKL -> VB07
#   AVKL -> VB08
#   AVKL -> VB09
#   AVKL -> VB10
#   AVKL -> VB11
#   AVKL -> VD01
#   AVKL -> VD02
#   AVKL -> VD03
#   AVKL -> VD04
#   AVKL -> VD05
#   AVKL -> VD06
#   AVKL -> VD07
#   AVKL -> VD08
#   AVKL -> VD09
#   AVKL -> VD10
#   AVKL -> VD11
#   AVKL -> VD12
#   AVKL -> VD13
#   AVKR -> ADAL
#   AVKR -> ADAR
#   AVKR -> ADEL
#   AVKR -> ADER
#   AVKR -> ADFL
#   AVKR -> ADFR
#   AVKR -> AIAL
#   AVKR -> AIAR
#   AVKR -> ALA
#   AVKR -> ALML
#   AVKR -> ALMR
#   AVKR -> AS01
#   AVKR -> AS02
#   AVKR -> AS03
#   AVKR -> AS04
#   AVKR -> AS05
#   AVKR -> AS06
#   AVKR -> AS07
#   AVKR -> AS08
#   AVKR -> AS09
#   AVKR -> AS10
#   AVKR -> AS11
#   AVKR -> ASJL
#   AVKR -> ASJR
#   AVKR -> AVAL
#   AVKR -> AVAR
#   AVKR -> AVBL
#   AVKR -> AVBR
#   AVKR -> AVDL
#   AVKR -> AVDR
#   AVKR -> AVEL
#   AVKR -> AVER
#   AVKR -> AVFL
#   AVKR -> AVFR
#   AVKR -> AVG
#   AVKR -> AVKL
#   AVKR -> AVKR
#   AVKR -> AVM
#   AVKR -> DA01
#   AVKR -> DA02
#   AVKR -> DA03
#   AVKR -> DA04
#   AVKR -> DA05
#   AVKR -> DA06
#   AVKR -> DA07
#   AVKR -> DA08
#   AVKR -> DA09
#   AVKR -> DB01
#   AVKR -> DB02
#   AVKR -> DB03
#   AVKR -> DB04
#   AVKR -> DB05
#   AVKR -> DB06
#   AVKR -> DB07
#   AVKR -> DD01
#   AVKR -> DD02
#   AVKR -> DD03
#   AVKR -> DD04
#   AVKR -> DD05
#   AVKR -> DD06
#   AVKR -> DVA
#   AVKR -> FLPL
#   AVKR -> FLPR
#   AVKR -> HSNL
#   AVKR -> HSNR
#   AVKR -> I1L
#   AVKR -> I1R
#   AVKR -> I3
#   AVKR -> I4
#   AVKR -> IL2DL
#   AVKR -> IL2DR
#   AVKR -> IL2L
#   AVKR -> IL2R
#   AVKR -> IL2VL
#   AVKR -> IL2VR
#   AVKR -> LUAL
#   AVKR -> LUAR
#   AVKR -> M1
#   AVKR -> M3L
#   AVKR -> M3R
#   AVKR -> M4
#   AVKR -> M5
#   AVKR -> MCL
#   AVKR -> MCR
#   AVKR -> MI
#   AVKR -> NSML
#   AVKR -> NSMR
#   AVKR -> PDA
#   AVKR -> PDB
#   AVKR -> PDEL
#   AVKR -> PDER
#   AVKR -> PHCL
#   AVKR -> PHCR
#   AVKR -> PLML
#   AVKR -> PLMR
#   AVKR -> PQR
#   AVKR -> PVCL
#   AVKR -> PVCR
#   AVKR -> PVDL
#   AVKR -> PVDR
#   AVKR -> PVNL
#   AVKR -> PVNR
#   AVKR -> PVPL
#   AVKR -> PVPR
#   AVKR -> PVQL
#   AVKR -> PVQR
#   AVKR -> PVR
#   AVKR -> PVT
#   AVKR -> PVWL
#   AVKR -> PVWR
#   AVKR -> RIAL
#   AVKR -> RIAR
#   AVKR -> RIBL
#   AVKR -> RIBR
#   AVKR -> RICL
#   AVKR -> RICR
#   AVKR -> RID
#   AVKR -> RIGL
#   AVKR -> RIGR
#   AVKR -> RIH
#   AVKR -> RIML
#   AVKR -> RIMR
#   AVKR -> RIS
#   AVKR -> RMDDL
#   AVKR -> RMDDR
#   AVKR -> RMDL
#   AVKR -> RMDR
#   AVKR -> RMDVL
#   AVKR -> RMDVR
#   AVKR -> RMED
#   AVKR -> RMEV
#   AVKR -> RMGL
#   AVKR -> RMGR
#   AVKR -> RMHL
#   AVKR -> RMHR
#   AVKR -> SABD
#   AVKR -> SABVL
#   AVKR -> SABVR
#   AVKR -> SDQL
#   AVKR -> SDQR
#   AVKR -> SMDDL
#   AVKR -> SMDDR
#   AVKR -> SMDVL
#   AVKR -> SMDVR
#   AVKR -> URADL
#   AVKR -> URADR
#   AVKR -> URAVL
#   AVKR -> URAVR
#   AVKR -> URBL
#   AVKR -> URBR
#   AVKR -> URXL
#   AVKR -> URXR
#   AVKR -> URYDL
#   AVKR -> URYDR
#   AVKR -> URYVL
#   AVKR -> URYVR
#   AVKR -> VA01
#   AVKR -> VA02
#   AVKR -> VA03
#   AVKR -> VA04
#   AVKR -> VA05
#   AVKR -> VA06
#   AVKR -> VA07
#   AVKR -> VA08
#   AVKR -> VA09
#   AVKR -> VA10
#   AVKR -> VA11
#   AVKR -> VA12
#   AVKR -> VB01
#   AVKR -> VB02
#   AVKR -> VB03
#   AVKR -> VB04
#   AVKR -> VB05
#   AVKR -> VB06
#   AVKR -> VB07
#   AVKR -> VB08
#   AVKR -> VB09
#   AVKR -> VB10
#   AVKR -> VB11
#   AVKR -> VD01
#   AVKR -> VD02
#   AVKR -> VD03
#   AVKR -> VD04
#   AVKR -> VD05
#   AVKR -> VD06
#   AVKR -> VD07
#   AVKR -> VD08
#   AVKR -> VD09
#   AVKR -> VD10
#   AVKR -> VD11
#   AVKR -> VD12
#   AVKR -> VD13
# Per-receptor connectomes available:
#   dmsr-5: 116 connections
#   dmsr-6: 80 connections
#   dmsr-7: 204 connections
#   frpr-7: 120 connections
#
# ============================================================
# FLP-1 -> DMSR-7 Connectome:
# ============================================================
# Shape: (302, 302)
# Total connections: 204
#
# FLP-1/DMSR-7 connections (204 total):
#   AVKL -> ALA
#   AVKL -> ALML
#   AVKL -> ALMR
#   AVKL -> AS01
#   AVKL -> AS02
#   AVKL -> AS03
#   AVKL -> AS04
#   AVKL -> AS05
#   AVKL -> AS06
#   AVKL -> AS07
#   AVKL -> AS08
#   AVKL -> AS09
#   AVKL -> AS10
#   AVKL -> AS11
#   AVKL -> AVAL
#   AVKL -> AVAR
#   AVKL -> AVBL
#   AVKL -> AVBR
#   AVKL -> AVDL
#   AVKL -> AVDR
#   AVKL -> AVFL
#   AVKL -> AVFR
#   AVKL -> AVKL
#   AVKL -> AVKR
#   AVKL -> AVM
#   AVKL -> DA01
#   AVKL -> DA02
#   AVKL -> DA03
#   AVKL -> DA04
#   AVKL -> DA05
#   AVKL -> DA06
#   AVKL -> DA07
#   AVKL -> DA08
#   AVKL -> DA09
#   AVKL -> DB01
#   AVKL -> DB02
#   AVKL -> DB03
#   AVKL -> DB04
#   AVKL -> DB05
#   AVKL -> DB06
#   AVKL -> DB07
#   AVKL -> DVA
#   AVKL -> HSNL
#   AVKL -> HSNR
#   AVKL -> PDB
#   AVKL -> PVCL
#   AVKL -> PVCR
#   AVKL -> PVPL
#   AVKL -> PVPR
#   AVKL -> PVR
#   AVKL -> PVT
#   AVKL -> RIAL
#   AVKL -> RIAR
#   AVKL -> RIBL
#   AVKL -> RIBR
#   AVKL -> RICL
#   AVKL -> RICR
#   AVKL -> RID
#   AVKL -> RIH
#   AVKL -> RIML
#   AVKL -> RIMR
#   AVKL -> RMDDL
#   AVKL -> RMDDR
#   AVKL -> RMDVL
#   AVKL -> RMDVR
#   AVKL -> RMED
#   AVKL -> RMEV
#   AVKL -> RMHL
#   AVKL -> RMHR
#   AVKL -> SABD
#   AVKL -> SABVL
#   AVKL -> SABVR
#   AVKL -> SDQL
#   AVKL -> SDQR
#   AVKL -> SMDDL
#   AVKL -> SMDDR
#   AVKL -> SMDVL
#   AVKL -> SMDVR
#   AVKL -> URBL
#   AVKL -> URBR
#   AVKL -> VA01
#   AVKL -> VA02
#   AVKL -> VA03
#   AVKL -> VA04
#   AVKL -> VA05
#   AVKL -> VA06
#   AVKL -> VA07
#   AVKL -> VA08
#   AVKL -> VA09
#   AVKL -> VA10
#   AVKL -> VA11
#   AVKL -> VB01
#   AVKL -> VB02
#   AVKL -> VB03
#   AVKL -> VB04
#   AVKL -> VB05
#   AVKL -> VB06
#   AVKL -> VB07
#   AVKL -> VB08
#   AVKL -> VB09
#   AVKL -> VB10
#   AVKL -> VB11
#   AVKR -> ALA
#   AVKR -> ALML
#   AVKR -> ALMR
#   AVKR -> AS01
#   AVKR -> AS02
#   AVKR -> AS03
#   AVKR -> AS04
#   AVKR -> AS05
#   AVKR -> AS06
#   AVKR -> AS07
#   AVKR -> AS08
#   AVKR -> AS09
#   AVKR -> AS10
#   AVKR -> AS11
#   AVKR -> AVAL
#   AVKR -> AVAR
#   AVKR -> AVBL
#   AVKR -> AVBR
#   AVKR -> AVDL
#   AVKR -> AVDR
#   AVKR -> AVFL
#   AVKR -> AVFR
#   AVKR -> AVKL
#   AVKR -> AVKR
#   AVKR -> AVM
#   AVKR -> DA01
#   AVKR -> DA02
#   AVKR -> DA03
#   AVKR -> DA04
#   AVKR -> DA05
#   AVKR -> DA06
#   AVKR -> DA07
#   AVKR -> DA08
#   AVKR -> DA09
#   AVKR -> DB01
#   AVKR -> DB02
#   AVKR -> DB03
#   AVKR -> DB04
#   AVKR -> DB05
#   AVKR -> DB06
#   AVKR -> DB07
#   AVKR -> DVA
#   AVKR -> HSNL
#   AVKR -> HSNR
#   AVKR -> PDB
#   AVKR -> PVCL
#   AVKR -> PVCR
#   AVKR -> PVPL
#   AVKR -> PVPR
#   AVKR -> PVR
#   AVKR -> PVT
#   AVKR -> RIAL
#   AVKR -> RIAR
#   AVKR -> RIBL
#   AVKR -> RIBR
#   AVKR -> RICL
#   AVKR -> RICR
#   AVKR -> RID
#   AVKR -> RIH
#   AVKR -> RIML
#   AVKR -> RIMR
#   AVKR -> RMDDL
#   AVKR -> RMDDR
#   AVKR -> RMDVL
#   AVKR -> RMDVR
#   AVKR -> RMED
#   AVKR -> RMEV
#   AVKR -> RMHL
#   AVKR -> RMHR
#   AVKR -> SABD
#   AVKR -> SABVL
#   AVKR -> SABVR
#   AVKR -> SDQL
#   AVKR -> SDQR
#   AVKR -> SMDDL
#   AVKR -> SMDDR
#   AVKR -> SMDVL
#   AVKR -> SMDVR
#   AVKR -> URBL
#   AVKR -> URBR
#   AVKR -> VA01
#   AVKR -> VA02
#   AVKR -> VA03
#   AVKR -> VA04
#   AVKR -> VA05
#   AVKR -> VA06
#   AVKR -> VA07
#   AVKR -> VA08
#   AVKR -> VA09
#   AVKR -> VA10
#   AVKR -> VA11
#   AVKR -> VB01
#   AVKR -> VB02
#   AVKR -> VB03
#   AVKR -> VB04
#   AVKR -> VB05
#   AVKR -> VB06
#   AVKR -> VB07
#   AVKR -> VB08
#   AVKR -> VB09
#   AVKR -> VB10
#   AVKR -> VB11
# Preassembled FLP-1/DMSR-7 connectome:
#   Shape: (302, 302)
#   Total connections: 204
#   Source neurons with outgoing: 2
#   Target neurons with incoming: 102
#
# Assembled FLP-1/DMSR-7 connectome:
#   Shape: (302, 302)
#   Total connections: 204
#   Source neurons with outgoing: 2
#   Target neurons with incoming: 102
# Common neurons in index: 302
# Common neurons in columns: 302
#
# Exact match: True
# All 302x302 = 91,204 entries match exactly!
#
# Source neurons (preassembled): ['AVKL', 'AVKR']
# Source neurons (assembled): ['AVKL', 'AVKR']
# Sources match: True
#
# Target neurons match: True
# Number of targets: 102
# ============================================================
# Intermediate Data Validation
# ============================================================
#
# 1. Pairing Info (RipollSanchez2023):
#    FLP-1 / DMSR-7 pair found: True
#    EC50: 1.42e-11
#
# 2. Release Data (sequencing:RipollSanchez2023):
#    FLP-1 column exists: True
#    Neurons releasing FLP-1: ['AVKL', 'AVKR']
#
# 3. Receptor Data (sequencing:RipollSanchez2023):
#    DMSR-7 column exists: True
#    Neurons expressing DMSR-7: 102
#
# 4. Connection Count Validation:
#    Expected: 2 sources × 102 targets = 204
#    Actual: 204
#    Match: True
